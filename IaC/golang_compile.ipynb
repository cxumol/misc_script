# %%
# !wget -qO- https://go.dev/dl/go1.25.5.linux-amd64.tar.gz | sudo tar -C /usr/local -xz && echo 'export PATH=$PATH:/usr/local/go/bin' | sudo tee /etc/profile.d/go.sh > /dev/null && source /etc/profile.d/go.sh && go version

# %%
# !/usr/local/go/bin/go mod init go_compile
# !/usr/local/go/bin/go get github.com/gorilla/websocket

# %%
# !CGO_ENABLED=0 GOOS=linux GOARCH=amd64 /usr/local/go/bin/go build -ldflags="-s -w" -o main main.go # && strip main && upx --best main

# %%
# !curl -F "reqtype=fileupload" -F "time=12h" -F "fileToUpload=@main" https://litterbox.catbox.moe/resources/internals/api.php

# %%
# !curl -F files[]=@ryl.7z https://uguu.se/upload

# %%
# !curl -k -F "file=@ryl.7z" -F "token=123" -F "model=0"  -X POST "https://tmp-cli.vx-cdn.com/app/upload_cli"
